# %%
import pandas as pd

# %%
df = pd.read_csv("data/data/newest_gm_reviews_2025-01-16.csv")

# %%
df
# Out:
#                                    id_review  \
# 0       ChdDSUhNMG9nS0VJQ0FnSUNfenNuYjR3RRAB
# 1       ChdDSUhNMG9nS0VJQ0FnSUNfMVBHRTh3RRAB
# 2       ChdDSUhNMG9nS0VJQ0FnSUNfcU5PQm1nRRAB
# 3        ChZDSUhNMG9nS0VJQ0FnSURmMzVfZElnEAE
# 4        ChZDSUhNMG9nS0VJQ0FnSUQtb05tZ2J3EAE
# ...                                      ...
# 114479  ChdDSUhNMG9nS0VJQ0FnSUNnMU15amxnRRAB
# 114480   ChZDSUhNMG9nS0VJQ0FnSUNBczlIYlR3EAE
# 114481   ChZDSUhNMG9nS0VJQ0FnSUNBaF9POVVREAE
# 114482   ChZDSUhNMG9nS0VJQ0FnSURBbFpIZ1p3EAE
# 114483  ChdDSUhNMG9nS0VJQ0FnSURReGZiYTJRRRAB
#
#                                                   caption relative_date  \
# 0       Super quick and great service. Reshmi and Roop...   8 hours ago
# 1                                                  Saiyda    3 days ago
# 2       Excellent service and styling! 10/10 recommend...    4 days ago
# 3       Good waxing and face massage service by Shaila...    5 days ago
# ...

# %%
df2 = pd.read_csv("data/naturals_chennai_locations_metadata.csv")

# %%
df2[df2["Area"] == "Nookampalayam"]
# Out:
#      Unnamed: 0 Location ID     City      City Area           Area  \
# 114         259       LOC_1  Chennai  Nookampalayam  Nookampalayam
#
#                          Name  \
# 114  Naturals Signature Salon
#
#                                                Address   Latitude  Longitude  \
# 114  1, Sristi Arcade, Sristi First Avenue, Cheran ...  12.896265  80.198108
#
#      Rating  Total Reviews                     Place ID  \
# 114     4.8            458  ChIJ5dJscNpbUjoRxlwAVwOEggE
#
#                                        Google Maps URL  \
# 114  https://www.google.com/maps/place/?q=place_id:...
#
#                                      full_location
# 114  Chennai NookampalayamNaturals Signature Salon

# %%
log_df = df.read_csv("logs/
