# %%
import logging
import googlemaps
import pandas as pd
from math import radians, cos, sin, sqrt, atan2

# %%
import pandas as pd
import logging
from math import radians, sin, cos, sqrt, atan2

# Helper function to calculate the distance between two points (Haversine formula)
def haversine(lat1, lon1, lat2, lon2):
    R = 6371.0  # Radius of the Earth in kilometers
    dlat = radians(lat2 - lat1)
    dlon = radians(lon2 - lon1)
    a = sin(dlat / 2) ** 2 + cos(radians(lat1)) * cos(radians(lat2)) * sin(dlon / 2) ** 2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))
    distance = R * c
    return distance

def extract_and_flag_nearby_salons_from_df(api_key, df):
    """
    Calculate distances between locations in a DataFrame and flag salons that are within 1 km of each other.

    Parameters:
        api_key (str): Google API key.
        df (pd.DataFrame): Input DataFrame with 'Latitude', 'Longitude', and 'Address' columns.

    Returns:
        pd.DataFrame: DataFrame with additional columns for nearby flags and distances.
    """
    logging.info("Starting the extract_and_flag_nearby_salons_from_df function")

    try:
        # Ensure required columns exist
        required_columns = {"Latitude", "Longitude", "Address"}
        if not required_columns.issubset(df.columns):
            raise ValueError(f"The input DataFrame must contain the columns: {required_columns}")

        # Add placeholder columns for nearby flag and distances
        df["Nearby Flag"] = "No"
        df["Nearby Salon Address"] = None
        df["Distance to Nearby Salon (km)"] = None

        # Calculate distances and flag nearby salons
        for i, loc1 in df.iterrows():
            for j, loc2 in df.iterrows():
                if i >= j:  # Avoid duplicate calculations and self-comparison
                    continue
                distance = haversine(loc1["Latitude"], loc1["Longitude"], loc2["Latitude"], loc2["Longitude"])
                if distance <= 1.0:  # Within 1 km
                    # Flag the salons and add nearby salon addresses and distances
                    df.at[i, "Nearby Flag"] = "Yes"
                    df.at[j, "Nearby Flag"] = "Yes"
                    if df.at[i, "Nearby Salon Address"] is None:
                        df.at[i, "Nearby Salon Address"] = loc2["Address"]
                        df.at[i, "Distance to Nearby Salon (km)"] = round(distance, 2)
                    if df.at[j, "Nearby Salon Address"] is None:
                        df.at[j, "Nearby Salon Address"] = loc1["Address"]
                        df.at[j, "Distance to Nearby Salon (km)"] = round(distance, 2)

        # Replace NaN values in flags, addresses, and distances
        df["Nearby Salon Address"] = df["Nearby Salon Address"].fillna("None")
        df["Distance to Nearby Salon (km)"] = df["Distance to Nearby Salon (km)"].fillna(0.0)

        logging.info("Successfully calculated distances and flagged nearby salons")
        return df

    except Exception as e:
        logging.error(f"An error occurred: {e}")
        return pd.DataFrame()  # Return an empty DataFrame in case of errors

# %%
df = pd.read_csv("data/naturals_chennai_locations_metadata.csv")

# %%
df.head()
# Out:
#    Unnamed: 0 Location ID                    City Area  \
# 0           0       LOC_1                     Alwarpet
# 1           1       LOC_2                     Alwarpet
# 2           2       LOC_3                     Alwarpet
# 3           3       LOC_4                     Alwarpet
# 4           8       LOC_1  Adambakkam, Brindavan Nagar
#
#                                                 Name  \
# 0  Naturals Salon & Spa CP Ramaswamy road , Alwar...
# 1                                Naturals Lounge TTK
# 2                           Naturals Signature Salon
# 3                                     Naturals Salon
# 4                                     Naturals Salon
#
#                                              Address   Latitude  Longitude  \
# 0  No.37, 1st Floor, CP Ramaswamy Iyer Rd, opp. t...  13.032512  80.256971
# 1  No.220, Mowbrays Flats, TT Krishnamachari Rd, ...  13.043691  80.259478
# 2  No: 24-25, Venkatakrishna Rd, above Spencer's ...  13.026759  80.261401
# 3  No 220, Mowbrays Flats, TT Krishnamachari Rd, ...  13.043618  80.259485
# 4  N37 First Flr, 2nd Street Shawalace Col, Brind...  12.986571  80.205181
#
#    Rating  Total Reviews                     Place ID  \
# 0     4.6           1078  ChIJB0quoslnUjoRf_vm8BiGHsM
# 1     4.6            656  ChIJfwi_pjZmUjoRtNJzL20D2-A
# 2     4.8           2818  ChIJT8VLUspnUjoRa_HrTUzVpa4
# 3     5.0              1  ChIJ1cEdFYpnUjoRBTQevSN3-mU
# 4     4.9            352  ChIJD93nXvxdUjoRinIO5qSoRrc
#
#                                      Google Maps URL
# 0  https://www.google.com/maps/place/?q=place_id:...
# 1  https://www.google.com/maps/place/?q=place_id:...
# 2  https://www.google.com/maps/place/?q=place_id:...
# 3  https://www.google.com/maps/place/?q=place_id:...
# 4  https://www.google.com/maps/place/?q=place_id:...

# %%
len(df)
# Out:
# 172

# %%
api_key = "AIzaSyB-wyVE7zyFMPwRKDQmw5fLrTluF_nAAxQ"

# %%
result_df = extract_and_flag_nearby_salons_from_df(api_key, df)
# Out:
# /var/folders/8n/h10xzq8574jgwdhlw0hn4gg80000gn/T/ipykernel_62413/1780532577.py:58: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["Distance to Nearby Salon (km)"] = df["Distance to Nearby Salon (km)"].fillna(0.0)

# %%
result_df.head()
# Out:
#    Unnamed: 0 Location ID                    City Area  \
# 0           0       LOC_1                     Alwarpet
# 1           1       LOC_2                     Alwarpet
# 2           2       LOC_3                     Alwarpet
# 3           3       LOC_4                     Alwarpet
# 4           8       LOC_1  Adambakkam, Brindavan Nagar
#
#                                                 Name  \
# 0  Naturals Salon & Spa CP Ramaswamy road , Alwar...
# 1                                Naturals Lounge TTK
# 2                           Naturals Signature Salon
# 3                                     Naturals Salon
# 4                                     Naturals Salon
#
#                                              Address   Latitude  Longitude  \
# 0  No.37, 1st Floor, CP Ramaswamy Iyer Rd, opp. t...  13.032512  80.256971
# 1  No.220, Mowbrays Flats, TT Krishnamachari Rd, ...  13.043691  80.259478
# 2  No: 24-25, Venkatakrishna Rd, above Spencer's ...  13.026759  80.261401
# 3  No 220, Mowbrays Flats, TT Krishnamachari Rd, ...  13.043618  80.259485
# 4  N37 First Flr, 2nd Street Shawalace Col, Brind...  12.986571  80.205181
#
#    Rating  Total Reviews                     Place ID  \
# 0     4.6           1078  ChIJB0quoslnUjoRf_vm8BiGHsM
# 1     4.6            656  ChIJfwi_pjZmUjoRtNJzL20D2-A
# 2     4.8           2818  ChIJT8VLUspnUjoRa_HrTUzVpa4
# 3     5.0              1  ChIJ1cEdFYpnUjoRBTQevSN3-mU
# 4     4.9            352  ChIJD93nXvxdUjoRinIO5qSoRrc
#
#                                      Google Maps URL Nearby Flag  \
# 0  https://www.google.com/maps/place/?q=place_id:...         Yes
# 1  https://www.google.com/maps/place/?q=place_id:...         Yes
# 2  https://www.google.com/maps/place/?q=place_id:...         Yes
# 3  https://www.google.com/maps/place/?q=place_id:...         Yes
# 4  https://www.google.com/maps/place/?q=place_id:...          No
#
#                                 Nearby Salon Address  \
# 0  No: 24-25, Venkatakrishna Rd, above Spencer's ...
# 1  No 220, Mowbrays Flats, TT Krishnamachari Rd, ...
# 2  No.37, 1st Floor, CP Ramaswamy Iyer Rd, opp. t...
# 3  No.220, Mowbrays Flats, TT Krishnamachari Rd, ...
# 4                                               None
#
#    Distance to Nearby Salon (km)
# 0                           0.80
# 1                           0.01
# 2                           0.80
# 3                           0.01
# 4                           0.00

# %%
result_df["Nearby Flag"].value_counts()
# Out:
# Nearby Flag
# Yes    95
# No     77
# Name: count, dtype: int64

# %%
result_df.to_csv("data/naturals_salons_with_flags_and_distances.csv")

# %%
# !pip install matplotlib basemap
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.9.4-cp39-cp39-macosx_11_0_arm64.whl (7.8 MB)
#      |████████████████████████████████| 7.8 MB 1.3 MB/s eta 0:00:01
# Collecting basemap
#   Downloading basemap-1.4.1-cp39-cp39-macosx_11_0_arm64.whl (569 kB)
#      |████████████████████████████████| 569 kB 39.9 MB/s eta 0:00:01
# Collecting kiwisolver>=1.3.1
#   Downloading kiwisolver-1.4.7-cp39-cp39-macosx_11_0_arm64.whl (64 kB)
#      |████████████████████████████████| 64 kB 10.6 MB/s eta 0:00:01
# Requirement already satisfied: pillow>=8 in ./proj_env/lib/python3.9/site-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: numpy>=1.23 in ./proj_env/lib/python3.9/site-packages (from matplotlib) (1.26.4)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.55.3-cp39-cp39-macosx_10_9_universal2.whl (2.8 MB)
#      |████████████████████████████████| 2.8 MB 35.9 MB/s eta 0:00:01
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.3.0-cp39-cp39-macosx_11_0_arm64.whl (249 kB)
#      |████████████████████████████████| 249 kB 34.0 MB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.7 in ./proj_env/lib/python3.9/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: packaging>=20.0 in ./proj_env/lib/python3.9/site-packages (from matplotlib) (24.2)
# Collecting importlib-resources>=3.2.0
#   Downloading importlib_resources-6.4.5-py3-none-any.whl (36 kB)
# Requirement already satisfied: pyparsing>=2.3.1 in ./proj_env/lib/python3.9/site-packages (from matplotlib) (3.2.0)
# Collecting cycler>=0.10
#   Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting packaging>=20.0
#   Downloading packaging-23.2-py3-none-any.whl (53 kB)
#      |████████████████████████████████| 53 kB 6.1 MB/s  eta 0:00:01
# Collecting matplotlib
#   Downloading matplotlib-3.8.4-cp39-cp39-macosx_11_0_arm64.whl (7.5 MB)
#      |████████████████████████████████| 7.5 MB 11.7 MB/s eta 0:00:01
# Collecting pyshp<2.4,>=1.2
#   Downloading pyshp-2.3.1-py2.py3-none-any.whl (46 kB)
#      |████████████████████████████████| 46 kB 8.2 MB/s  eta 0:00:01
# Collecting basemap-data<1.4,>=1.3.2
#   Downloading basemap_data-1.3.2-py2.py3-none-any.whl (30.5 MB)
#      |████████████████████████████████| 30.5 MB 21.5 MB/s eta 0:00:01
# Collecting pyproj<3.7.0,>=1.9.3
#   Downloading pyproj-3.6.1-cp39-cp39-macosx_11_0_arm64.whl (4.9 MB)
#      |████████████████████████████████| 4.9 MB 67.0 MB/s eta 0:00:01
# Requirement already satisfied: zipp>=3.1.0 in ./proj_env/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.21.0)
# Requirement already satisfied: certifi in ./proj_env/lib/python3.9/site-packages (from pyproj<3.7.0,>=1.9.3->basemap) (2024.2.2)
# Requirement already satisfied: six>=1.5 in ./proj_env/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Installing collected packages: packaging, kiwisolver, importlib-resources, fonttools, cycler, contourpy, pyshp, pyproj, matplotlib, basemap-data, basemap
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.2
#     Uninstalling packaging-24.2:
#       Successfully uninstalled packaging-24.2
# Successfully installed basemap-1.4.1 basemap-data-1.3.2 contourpy-1.3.0 cycler-0.12.1 fonttools-4.55.3 importlib-resources-6.4.5 kiwisolver-1.4.7 matplotlib-3.8.4 packaging-23.2 pyproj-3.6.1 pyshp-2.3.1
# WARNING: You are using pip version 21.2.4; however, version 24.3.1 is available.
# You should consider upgrading via the '/Users/madhumithakumar/Documents/google_reviews_tracker/proj_env/bin/python3 -m pip install --upgrade pip' command.

# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt

# Initialize the map
m = Basemap(projection='merc', llcrnrlat=-60, urcrnrlat=80,
            llcrnrlon=-180, urcrnrlon=180, resolution='i')

m.drawcoastlines()
m.drawcountries()

# Plot points
latitudes = [12.9716, 19.0760, 28.7041]  # Example latitudes
longitudes = [77.5946, 72.8777, 77.1025]  # Example longitudes
x, y = m(longitudes, latitudes)

m.scatter(x, y, marker='o', color='red', zorder=5)

plt.title("Locations on World Map")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 from mpl_toolkits.basemap import Basemap
#       2 import matplotlib.pyplot as plt
#       4 # Initialize the map
#
# File ~/Documents/google_reviews_tracker/proj_env/lib/python3.9/site-packages/mpl_toolkits/basemap/__init__.py:47
#      44 from mpl_toolkits.axes_grid1 import make_axes_locatable
#      46 import pyproj
# ---> 47 import _geoslib
#      48 from . proj import Proj
#      51 __version__ = "1.4.1"
#
# File src/_geoslib.pyx:1, in init _geoslib()
#
# ValueError: numpy.dtype size changed, may indicate binary incompatibility. Expected 96 from C header, got 88 from PyObject
